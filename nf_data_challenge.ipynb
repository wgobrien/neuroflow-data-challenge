# %% [markdown]
# # NeuroFlow Data Challenge
# ## Part 1
#
# Given the information you have and any light research you’d like to do on the topic, what insights can you draw? What assumptions have you made about the data? What are 2-3 additional pieces of information that would be important to collect? We are not looking for production-ready code, but we will assess both your approach to visualization and your technical abilities.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read in csv
gad = pd.read_csv("phq_all_final.csv")

# convert date columns to datetime objects
gad.date = pd.to_datetime(gad.date)
gad.patient_date_created = pd.to_datetime(gad.patient_date_created)

gad
# Out:
#                             date  patient_id  type       patient_date_created  \
# 0     2019-08-26 13:32:43.019162        8430  gad7 2019-06-03 13:23:02.635680
# 1     2019-11-15 17:55:11.364877        8430  gad7 2019-06-03 13:23:02.635680
# 2     2019-10-07 18:23:29.611351       14338  gad7 2019-06-03 13:32:30.668460
# 3     2019-11-04 20:16:28.610965       14338  gad7 2019-06-03 13:32:30.668460
# 4     2019-12-02 20:56:55.966354       14338  gad7 2019-06-03 13:32:30.668460
# ...                          ...         ...   ...                        ...
# 53693 2020-07-31 13:59:13.201741       10683  gad7 2020-07-31 13:54:20.164253
# 53694 2020-07-31 15:08:56.079027       12344  gad7 2020-07-31 15:06:51.043730
# 53695 2020-07-31 15:52:50.353265       17475  gad7 2020-07-31 15:40:07.726529
# 53696 2020-07-31 17:36:57.057913        9069  gad7 2020-07-31 17:33:27.096572
# 53697 2020-07-31 17:58:53.067462        4870  gad7 2020-07-31 17:58:21.004418
#
#        score
# 0          6
# ...

# %%
gad[gad.groupby(by=["patient_id"]).count().max() not gad.groupby(by=["patient_id"]).count()]
# Out:
#       date  patient_id type patient_date_created  score
# 0      NaT         NaN  NaN                  NaT    NaN
# 1      NaT         NaN  NaN                  NaT    NaN
# 2      NaT         NaN  NaN                  NaT    NaN
# 3      NaT         NaN  NaN                  NaT    NaN
# 4      NaT         NaN  NaN                  NaT    NaN
# ...    ...         ...  ...                  ...    ...
# 53693  NaT         NaN  NaN                  NaT    NaN
# 53694  NaT         NaN  NaN                  NaT    NaN
# 53695  NaT         NaN  NaN                  NaT    NaN
# 53696  NaT         NaN  NaN                  NaT    NaN
# 53697  NaT         NaN  NaN                  NaT    NaN
#
# [53698 rows x 5 columns]

# %%
patient_id = gad[gad.patient_id == 14338]

plt.figure(figsize=(8,6))
plt.plot(patient_id.date, patient_id.score)

plt.ylabel("score")
plt.xlabel("date of test")
plt.show()
